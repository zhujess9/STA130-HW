# %% [markdown]
# *Research Question 1:*
# Does the frequency of how often you keep in touch with your immediate family impact your mental health when living away from home?
#
# *Variables*
#
# - How often the individual visits home; measured ordinal (never, weekly, monthly, once a year, a few times a year)
# Why this variable: If the individual is regularly seeing their immediate family, there may not be a huge emotional strain of living away from home.
# - How far the individual is away from their family; measured ordinal (less than 50 km, 50-100 km, 100-500 km, 500+ km)
# Why this variable: Somewhat related to the first variable because the closer the individual is to their home, the more often they're able to visit. Another reason why is because simply having the reassurance of "I can go home whenever I need. My family are closeby" can relieve the strain of living away.
# - How close the individual's bonds are with their family; measured by scale(?), (1: not close at all - 5: extremely close)
# Why this variable: Some individuals who do not have a good relationship with their family may find it refreshing to have moved out. Their lack of contact with their family does not impact them as much as someone who is very close with their family.
# - How social the individual is with people outside their family; "I socially interact with non-family members: Daily, Weekly, Monthly, Rarely"
# Why this variable: Spending quality time with friends or other people outside of your family can also relieve the emotional strain becausse the individual is still having social interactions. Compared to an individual who is socially isolated, they may begin depend on their family for social fulfillment.
# - The individual's mental health history; could measure by nominal scale [ex: "has history of mental health issues" vs "no history of mental health issues"] or measured binary "Yes/No"
# Why this variable: We should consider the individual's mental health history since we are analyzing whether the question's objective will impact their mental health.
# - The individuals living situation; measured by nominal scale (living alone, w/roommates, living with non-immediate family, etc)
# Why this variable: Those who live with roommates or non-immediate family can still have their social fulfillment met since they are living closely around people. Those who are living alone may feel more isolated in comparison.
#
# *Analysis Performance*
#
# I could analyze data by using linear regression. My objective is to quantify whether frequence family contact will impact mental health. Using linear regression can assess the relationship between contact frequency and mental health scores, whilst controlling the variables listed.
#
# *My Hypothesis*
#
# Individuals who maintain frequent and quality contact with immediate family will have better mental health outcomes compared to those with less.
#
# If my analysis shows a significant positive correlation between frequent family contact and mental health scores (lowered levels of anxiety, stress, feelings of homesickness), it can suggest that regular communication helps improve mental well being. This would support my initial thought that strong familial ties can be critical for individuals living away from home, especially for the first time.

# %% [markdown]
# *Research Question 2:*
# Does gossiping (divisive) with others strengthens bonds and improve moods by creating shared connections?
#
# *Variables*
#
# - Bond Strength; measured by scale(?) (On a scale of 1-5, how close did you feel with this person before the conversation vs after the conversation?) Why this variable: I can quantify the level of bonding after gossiping and assess whether the bond has been strengthened.
# - Mood Change; measured by the individual rating how they feel after (How did you feel before gossiping vs after gossiping: "Very Negative" - "Very Positive". Why this variable: By measuring the mood change, I can see whether there has been an improvement in mood/if there has been a release of positive brain chemicals.
# - Gossiping Frequency; measured ordinal (daily, weekly, monthly). Why this variable: I'd want to see if those who gossip frequently would experience more frequent/increased levels of bonding experience or mood effects from those who don't gossip as much.
# - How comfortable someone is gossiping (potentially negatively about someone); measured by scale? ("Do you feel comfortable talking about other people?" "Yes, Somewhat, No, Depends"). Why this variable: I want to compare whether those who are hesitant of gossiping will feel more satisfied, if not the same, than those who are comfortable about gossiping.
#
# *Analysis Performance*
#
# Option 1: Descriptive statistics
#
# The goal would be to summarize data which will provide a distribution view of the main variables. I can calculate means, medians, stds for continuous variables such as bond strength and mood ratings. I can do a report count/percentage for categorical variables such as gossip frequency (may need to brainstorm more variables).
#
# Option 2: Linear regression
#
# The goal is to see how well the variables explain how close individuals feel towards each other and whether there has been an improvement in mood. If we consider bond strength and mood improvement are measured as continuous outcomes, the linear regression can show how well the variables can vary the outcomes.
#
# *My Hypothesis*
#
# Those who partake in divisive gossiping may feel closer with those they talk with because it creates a sense of community/pact since they found a common adversary. In turn, having someone who you feel agrees with you about someone else's character may strengthen your friendship and decrease loneliness, perhaps releasing dopamine and lifting moods. I want to also see if individuals feel like they relieved stress after gossiping, and if there was an improvement in mental wellbeing. However, reckless gossiping may lead someone into unwanted drama which can outcast them from social groups and have them end up ultimately isolated.

# %% [markdown]
# *Research Question 3:*
# Does having close family bonds contribute more to one's well-being over friendship/workplace relationships?
#
# *Variables*
# - Demographics (age, gender, socioeconomic status). These can impact one's social norms and what they seek in social connections.
# - Living situation (living alone, with family, with roommates). How someone's living situation is can influence their relationship dynamics.
# - Cultural Background. Different cultures have different dynamics that can vary to how someone will perceive their relationships.
# - Social Trauma History. If there had been a specific event that has negatively or positively impacted how someone views family, friends, or colleagues.
#
#
# The 3 main relationship types to analyze
#
# Familial Bonds:
# - Quality of family relationships ("How supportive do you find  your family?" on a scale of 1-5)
# - Emotional vulnerabiblity ("How close do you think you are to your family?" on a scale of 1-5)
# - General Reflection ("I think my family has had a positive impact on who I've become today", Agree, Somewhat Agree, Somewhat Disagree, Disagree)
#
# Quality of Friendship:
# - Trust + Loyalty ("I feel like I can rely and confide in my close friends" on a scale of 1-5)
# - Closeness ("I think me and my friends share a strong bond" on a scale of 1-5)
# - General Reflection ("I think my circle of friends have had a positive impact on who I've become today", Agree, Somewhat Agree, Somewhat Disagree, Disagree)
#
# Workplace Relationships:
# - Relationship Quality ("How supportive are your colleagues?" on a scale of 1-5)
# - Trust + Communication ("How freely are you able to talk to your workplace relationships?" on a scale of 1-5)
# - General Reflection ("I think the people I work with have had a positive impact on who I've become today", Agree, Somewhat Agree, Somewhat Disagree, Disagree)
#
#
# We need to have a way to assess if relationships improved one's mental health status. We can measure things such  as the levels of anxiety, stress, depression, mood, and general outlook on life.
#
#
# *Analysis Performance*
#
# Option 1: Descriptive statistics
#
# The goal would be to summarize data which will provide a distribution view of the main variables. The focus would be on the main types of relationships and their correlation to well-being. I can calculate means, medians, stds for family quality, friendship, workplace relationships and life satisfaction/mental health. I should look for initial trends in how different relationship types will lead to different scores.
#
# Option 2: Linear regression
#
# The goal is to see the well-being scores while controlling the 3 different types of relationships simultaneously. Using a linear regression model can directly show this while holding other variables constantly.
#
# *My Hypothesis*
#
# I hypothesis that family bond will have the most impact to one's well-being. These people are the who you are raised by, who you spend arguably the most time with. They shape your first perceptions of people and have the ultimate impact on how you grow.
